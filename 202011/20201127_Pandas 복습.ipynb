# %% [markdown]
# # 판다스 복습

# %% [markdown]
# ## 판다스 시작 - 파일을 DataFrame으로 로딩, 기본 API

# %%
# pandas를 pd로 엥리리어스(alias)해 임포트하는 것이 관례이다.
import pandas as pd

# 데이터 불러오기
# read_csv(데이터 파일 경로명)
titanic_df = pd.read_csv('titanic_train.csv')

# 데이터 확인하기
# head(n), tail(n) : n값을 설정하여 보고 싶은 만큼 데이터를 볼 수 있다. n값을 비워두면 5개 항목을 볼 수 있다.
# 데이터 중 앞의 3개 보기
titanic_df.head(3)
# 데이터 중 뒤의 3개 보기
titanic_df.tail(3)
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 데이터 크기 확인하기
# shape
print('DataFrame 크기 :', titanic_df.shape)
# Out:
# DataFrame 크기 : (891, 12)

# %%
# info() : 총 데이터 건수와 데이터 타입, Null 건수에 대해서 알 수 있다.
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# describe() : 칼럼별 숫자형 데이터값의 n-percentile 분포도, 평균값, 최댓값, 최솟값에 대해서 알 수 있다.
# 오직 숫자형(int, float 등) 칼럼의 분포도만 조사하며 자동으로 object 타입의 칼럼은 출력에서 제외시킨다.
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# value_counts() : 해당 칼럼값의 유형과 건수를 확인할 수 있다.
value_cnt = titanic_df['Pclass'].value_counts()
print(value_cnt)
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# ## DataFrame과 리스트, 딕셔너리, 넘파이 ndarray 상호 변환
#  - DataFrame은 기본적으로 행과 열을 가지는 2차원 데이터이다. 따라서 2차원 이하의 데이터들만 DataFrame으로 변환될 수 있다.
#
# ### 1차원 데이터 - list, ndarray

# %%
import numpy as np

col_name1 = ['col1']
list1 = [1, 2, 3]
array1 = np.array(list1)
print('array1 shape :', array1.shape)

print()
print()

# 리스트를 이용해 DataFrame 생성
df_list1 = pd.DataFrame(list1, columns=col_name1)
print('1차원 리스트로 만든 DataFrame :\n', df_list1)

print()
print()

# 넘파이 ndarray를 이용해 DataFrame 생성
df_array1 = pd.DataFrame(array1, columns=col_name1)
print('1차원 ndarray로 만든 DataFrame:\n', df_array1)
# Out:
# array1 shape : (3,)
#
#
# 1차원 리스트로 만든 DataFrame :
#     col1
# 0     1
# 1     2
# 2     3
#
#
# 1차원 ndarray로 만든 DataFrame:
#     col1
# 0     1
# 1     2
# 2     3

# %% [markdown]
# ### 2차원 데이터 - list, ndarray

# %%
# 3개의 칼럼명이 필요함
col_name2 = ['col1', 'col2', 'col3']

# 2행x3열 형태의 리스트 생성한 뒤 이를 DataFrame으로 변환한다.
list2 = [[1, 2, 3], [11, 12, 13]]
df_list2 = pd.DataFrame(list2, columns=col_name2)
print('2차원 리스트로 만든 DataFrame:\n', df_list2)

print()
print()

# 2행x3열 형태의 ndarray 생성한 뒤 이를 DataFrame으로 변환한다.
array2 = np.array(list2)
df_array2 = pd.DataFrame(array2, columns=col_name2)
print('2차원 ndarray로 만든 DataFrame:\n', df_array2)
# Out:
# 2차원 리스트로 만든 DataFrame:
#     col1  col2  col3
# 0     1     2     3
# 1    11    12    13
#
#
# 2차원 ndarray로 만든 DataFrame:
#     col1  col2  col3
# 0     1     2     3
# 1    11    12    13

# %% [markdown]
# ### dictionary

# %%
dict = {'col1': [1, 11], 'col2': [2, 22], 'col3': [3, 33]}
df_dict = pd.DataFrame(dict)
print('dictionary로 만든 DataFrame:\n', df_dict)
# Out:
# dictionary로 만든 DataFrame:
#     col1  col2  col3
# 0     1     2     3
# 1    11    22    33

# %% [markdown]
# ### DataFrame을 ndarray, list, dictionary로 변환

# %%
print('DataFrame을 ndarray로 변환')
array3 = df_dict.values
print('df_dict.values 타입 :', type(array3))
print('df_dict.values shape :', array3.shape)
print(array3)

print()
print()

print('DataFrame을 list로 변환')
list3 = df_dict.values.tolist()
print('df_dict.values.tolist() 타입 :', type(list3))
print(list3)

print()
print()

print('DataFrame을 딕셔너리로 변환')
dict3 = df_dict.to_dict('list')
print('df_dict.to_dict() 타입 :', type(dict3))
print(dict3)
# Out:
# DataFrame을 ndarray로 변환
# df_dict.values 타입 : <class 'numpy.ndarray'>
# df_dict.values shape : (2, 3)
# [[ 1  2  3]
#  [11 22 33]]
#
#
# DataFrame을 list로 변환
# df_dict.values.tolist() 타입 : <class 'list'>
# [[1, 2, 3], [11, 22, 33]]
#
#
# DataFrame을 딕셔너리로 변환
# df_dict.to_dict() 타입 : <class 'dict'>
# {'col1': [1, 11], 'col2': [2, 22], 'col3': [3, 33]}

# %% [markdown]
# ### DataFrame의 칼럼 데이터 세트 생성과 수정

# %%
# Titanic DataFrame의 새로운 칼럼 Age_0을 추가하고 일괄적으로 0 값을 할당하면 다음과 같다.
titanic_df['Age_0'] = 0
titanic_df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_0
# 0      0         A/5 21171   7.2500   NaN        S      0
# 1      0          PC 17599  71.2833   C85        C      0
# 2      0  STON/O2. 3101282   7.9250   NaN        S      0

# %%
# 다음과 같이도 사용 가능하다.
titanic_df['Age_by_10'] = titanic_df['Age']*10
titanic_df['Family_No'] = titanic_df['SibSp'] + titanic_df['Parch'] + 1
titanic_df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_0  Age_by_10  \
# 0      0         A/5 21171   7.2500   NaN        S      0      220.0
# 1      0          PC 17599  71.2833   C85        C      0      380.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S      0      260.0
#
#    Family_No
# 0          2
# 1          2
# 2          1

# %% [markdown]
# ### DataFrame 데이터 삭제
#  - DataFrame.drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise')
#  - axis = 0 : Row
#  - axis = 1 : Column

# %%
titanic_drop_df = titanic_df.drop('Age_0', axis=1)
print(titanic_drop_df.head(3))

print()
print()

drop_list = ['Age_0', 'Age_by_10', 'Family_No']
drop_result = titanic_df.drop(drop_list, axis=1, inplace = True)
print('drop_result 결과값', drop_result)

print()
print()

# inplace를 사용하게 되면 titanic_df 자체의 값도 바뀌게 된다.
print('titanic_df 결과값')
titanic_df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_by_10  Family_No
# 0      0         A/5 21171   7.2500   NaN        S      220.0          2
# 1      0          PC 17599  71.2833   C85        C      380.0          2
# 2      0  STON/O2. 3101282   7.9250   NaN        S      260.0          1
#
#
# drop_result 결과값 None
#
#
# titanic_df 결과값
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
# ...

# %%
# Row 데이터 삭제
row_drop = titanic_df.drop([0, 1, 2], axis=0)
print(row_drop.head(3))
# Out:
#    PassengerId  Survived  Pclass  \
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#    Ticket     Fare Cabin Embarked
# 3  113803  53.1000  C123        S
# 4  373450   8.0500   NaN        S
# 5  330877   8.4583   NaN        Q

# %% [markdown]
# ### 데이터 셀렉션 및 필터링
#  - DataFrame 뒤에 있는 []는 칼럼만 지정할 수 있는 '칼럼 지정연산자'로 이해하는게 혼돈을 막는 가장 좋은 방법이다.

# %%
print('단일 칼럼 데이터 추출 :\n', titanic_df['Pclass'].head(3))

print()
print()

print('여러 칼럼의 데이터 추출 :\n', titanic_df[['Survived', 'Pclass']].head(3))
# Out:
# 단일 칼럼 데이터 추출 :
#  0    3
# 1    1
# 2    3
# Name: Pclass, dtype: int64
#
#
# 여러 칼럼의 데이터 추출 :
#     Survived  Pclass
# 0         0       3
# 1         1       1
# 2         1       3

# %%
print('로우 데이터 추출')
titanic_df[0:2]
# Out:
# 로우 데이터 추출
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# ### 정렬, Aggregation 함수, GroupBy 적용
#  - DataFrame, Series의 정렬 - sort_values()

# %%
# 1개의 칼럼을 정렬
titanic_sorted = titanic_df.sort_values(by=['Name'])
titanic_sorted.head(3)
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 845          846         0       3               Abbing, Mr. Anthony    male
# 746          747         0       3       Abbott, Mr. Rossmore Edward    male
# 279          280         1       3  Abbott, Mrs. Stanton (Rosa Hunt)  female
#
#       Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 845  42.0      0      0  C.A. 5547   7.55   NaN        S
# 746  16.0      1      1  C.A. 2673  20.25   NaN        S
# 279  35.0      1      1  C.A. 2673  20.25   NaN        S

# %%
# 여러 개의 칼럼을 내림차순으로 정렬
titanic_sorted = titanic_df.sort_values(by=['Pclass', 'Name'], ascending=False)
titanic_sorted.head(3)
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 868          869         0       3      van Melkebeke, Mr. Philemon  male
# 153          154         0       3  van Billiard, Mr. Austin Blyler  male
# 282          283         0       3        de Pelsmaeker, Mr. Alfons  male
#
#       Age  SibSp  Parch    Ticket  Fare Cabin Embarked
# 868   NaN      0      0    345777   9.5   NaN        S
# 153  40.5      0      2  A/5. 851  14.5   NaN        S
# 282  16.0      0      0    345778   9.5   NaN        S

# %% [markdown]
# - Aggregation 함수 적용 : min, max, sum, count

# %%
titanic_df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
titanic_df[['Age', 'Fare']].mean()
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %% [markdown]
#  - groupby() 적용

# %%
titanic_groupby = titanic_df.groupby(by='Pclass')
print(type(titanic_groupby))

print()
print()

titanic_groupby = titanic_df.groupby('Pclass').count()
titanic_groupby
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
titanic_groupby = titanic_df.groupby('Pclass')[['PassengerId', 'Survived']].count()
titanic_groupby
# Out:
#         PassengerId  Survived
# Pclass
# 1               216       216
# 2               184       184
# 3               491       491

# %%
titanic_df.groupby('Pclass')['Age'].agg([max, min])
# Out:
#          max   min
# Pclass
# 1       80.0  0.92
# 2       70.0  0.67
# 3       74.0  0.42

# %%
agg_format={'Age': 'max', 'SibSp': 'sum', 'Fare': 'mean'}
titanic_df.groupby('Pclass').agg(agg_format)
# Out:
#          Age  SibSp       Fare
# Pclass
# 1       80.0     90  84.154687
# 2       70.0     74  20.662183
# 3       74.0    302  13.675550

# %% [markdown]
# ###
# ### 결손 데이터 처리하기
#  - isna() : NaN 여부를 확인하는 API
#  - fillna() : NaN 값을 다른 값으로 대체하는 API

# %%
titanic_df.isna().head(3)
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False  False     False
# 2  False   True     False

# %%
titanic_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_df['Cabin'] = titanic_df['Cabin'].fillna('빈곳')
titanic_df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    빈곳        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    빈곳        S

# %%
titanic_df['Age'] = titanic_df['Age'].fillna(titanic_df['Age'].mean())
titanic_df['Embarked'] = titanic_df['Embarked'].fillna('S')
titanic_df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# ###
# ### apply lambda 식으로 데이터 가공

# %%
titanic_df['Name_len'] = titanic_df['Name'].apply(lambda x: len(x))
titanic_df[['Name', 'Name_len']].head(3)
# Out:
#                                                 Name  Name_len
# 0                            Braund, Mr. Owen Harris        23
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...        51
# 2                             Heikkinen, Miss. Laina        22

# %%
titanic_df['Child_Adult'] = titanic_df['Age'].apply(lambda x: 'Child' if x <= 15 else 'Adult')
titanic_df[['Age', 'Child_Adult']].head(8)
# Out:
#          Age Child_Adult
# 0  22.000000       Adult
# 1  38.000000       Adult
# 2  26.000000       Adult
# 3  35.000000       Adult
# 4  35.000000       Adult
# 5  29.699118       Adult
# 6  54.000000       Adult
# 7   2.000000       Child

# %%
titanic_df['Age_cat'] = titanic_df['Age'].apply(lambda x: 'Child' if x<=15 else('Adult' if x <= 60 else 'Elderly'))
titanic_df['Age_cat'].value_counts()
# Out:
# Adult      786
# Child       83
# Elderly     22
# Name: Age_cat, dtype: int64

# %%
def get_category(age):
    if age <= 5: return 'Baby'
    elif age <= 12: return 'Child'
    elif age <= 18: return 'Teenager'
    elif age <= 25: return 'Student'
    elif age <= 35: return 'Young Adult'
    elif age <= 60: return 'Adult'
    else: return 'Elderly'
    
# labmda 식에 위에서 생성한 get_category() 함수를 반환값으로 지정
# get_category(x)는 입력값으로 'Age' 칼럼 값을 받아서 해당하는 cat 반환
titanic_df['Age_cat'] = titanic_df['Age'].apply(lambda x : get_category(x))
titanic_df[['Age', 'Age_cat']].head()
# Out:
#     Age      Age_cat
# 0  22.0      Student
# 1  38.0        Adult
# 2  26.0  Young Adult
# 3  35.0  Young Adult
# 4  35.0  Young Adult
