# %% [markdown]
# # 2020.12.01
# # 인공지능 강의 18일차
#
#
# =======================================================================
#
# 데이터마이닝.pptx
#
# ![20201201.png](attachment:20201201.png)
#
#  - Association analysis
#  - Cluster analysis
#  - Outlier analysis
#  - Trend and evolution analysis
#  - Other pattern-directed or statistical analysis
#
# ***Top-10 Most Popular Data Mining Algorithms***
#
# =======================================================================
#
# ## Deep Learning
#
# ### Neural Network
#  - 단층 퍼셉트론 : xor 문제를 해결하지 못한다.
#  - 다층 퍼셉트론
#  - 역전파 알고리즘(Back Propagation Algorithm) : Feed-Forward step, Back-Propagation step
