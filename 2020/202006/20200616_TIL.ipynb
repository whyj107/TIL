# %% [markdown]
# 20200616
#
# # 컴퓨터
#
#  - 알고리즘(코드워) : Moving Zeros To The End
#  - 포트폴리오 정리 : Holter Monitor, Mat Fit, Treadmill
#  - 구름 EDU : node.js
#
# #### 알고리즘 문제를 풀었는데 다른 풀이를 보니 람다로 푸는 방법이 있었다. 정확히는 sorted를 이용한 것이였는데 전에 풀었는데도 아직 익숙하지 않아서 인지 저 방법은 바로 바로 떠오르지 않는다. 좀 더 반복 연습을 해야 할 것 같다.
#
# #### 친구의 포트폴리오를 봤는데 내 것의 비해서 자세히 기술해 둬서 너무 놀라웠다. 포폴 정리해서 언니에게 보여줬는데 피드백이 궁금하다.
#
# #### 드디어 저 화면을 뽑아냈다. 정말 간단한건데.... 왜이렇게 해맨건지... Atom이 아직 익숙하지 않은데 재미있는 에디터같다.

# %% [markdown]
# atom에서 터미널을 쓰고 싶으면 File - Setting - Install에서 platformio-ide-terminal을 다운받아야한다.

# %% [markdown]
# ![20200616.PNG](attachment:20200616.PNG)
